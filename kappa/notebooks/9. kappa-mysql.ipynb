-- %%
mysql://scott:tiger@mysql:3306/default

-- %%
show tables;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>Tables_in_default</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>castings</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>countries</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>events_agg</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>events_v2</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>genres</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>movies</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>peoples</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>purchase_20201025</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>purchase_20201026</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>rates</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>seoul_popular_trip</td>
-- ...

-- %%
select start, count(1) from events_v2 group by start order by start asc;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>start</th>
--       <th>count(1)</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>2022-10-01 07:40:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>2022-10-01 07:41:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>2022-10-01 07:42:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>2022-10-01 07:43:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>2022-10-01 07:44:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>2022-10-01 07:45:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>2022-10-01 07:46:00</td>
--       <td>10</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>2022-10-01 07:47:00</td>
-- ...

-- %%
-- drop table events_agg;
-- Out:
-- This result object does not return rows. It has been closed automatically.
